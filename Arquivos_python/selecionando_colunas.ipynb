# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\supor\Downloads\SQL_Server\arquivos_csv\Clientes.csv" , delimiter=',')
df.head(10)
# Out:
#    id           created_at first_name last_name                  email  \
# 0   0  2017-11-01 14:45:41      Marta     Jesus                    NaN
# 1   1  2017-10-16 00:50:39      Luana   Almeida                    NaN
# 2   2  2018-06-16 17:51:29      Frida    Mendes    frida@meu_email.com
# 3   3  2018-01-17 03:02:58    Daniela   Avelino    daniela@exemplo.com
# 4   4  2018-08-06 07:24:16    Romário  Teixeira                    NaN
# 5   5  2018-01-05 17:20:49    Marcelo   Barroso                    NaN
# 6   6  2018-06-18 11:17:42  Cristiano    Elísio  cristiano@exemplo.com
# 7   7  2018-02-08 12:36:09    Everton   Barbosa  everton@meu_email.com
# 8   8  2017-12-16 20:47:03   Gabriela     Alves   gabriela@exemplo.com
# 9   9  2018-11-11 11:48:41       Luan      Dias       luan@exemplo.com
#
#     cell_phone country              state  \
# 0  9 9102-7834  Brasil               Acre
# 1  9 7328-8718  Brasil  Rio Grande do Sul
# 2  9 5906-7552  Brasil          São Paulo
# ...

# %%
# selecionando colunas especificas
colunas = ["id", "first_name","last_name","email","cell_phone"]
dfcolunas = df[colunas]
df['email'] =   df['email'].fillna('Sem e-mail') # alterando valores nulos
dfcolunas.head(30)
# Out:
#     id first_name    last_name                  email   cell_phone
# 0    0      Marta        Jesus             Sem e-mail  9 9102-7834
# 1    1      Luana      Almeida             Sem e-mail  9 7328-8718
# 2    2      Frida       Mendes    frida@meu_email.com  9 5906-7552
# 3    3    Daniela      Avelino    daniela@exemplo.com  9 4642-9486
# 4    4    Romário     Teixeira             Sem e-mail  9 3093-6522
# 5    5    Marcelo      Barroso             Sem e-mail  9 2830-2088
# 6    6  Cristiano       Elísio  cristiano@exemplo.com  9 3532-8404
# 7    7    Everton      Barbosa  everton@meu_email.com  9 2553-4087
# 8    8   Gabriela        Alves   gabriela@exemplo.com  9 1353-8433
# 9    9       Luan         Dias       luan@exemplo.com  9 2417-3678
# 10  10    Mariana        Alves  mariana@meu_email.com  9 1846-6377
# 11  11      James  Albuquerque             Sem e-mail  9 2430-5905
# 12  12      Carol      Barboza      carol@exemplo.com  9 8487-3501
# ...
